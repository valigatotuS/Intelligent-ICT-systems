# %% [markdown]
# # Decision trees

# %% [markdown]
# Task1.
#
# Train and fine-tune a Decision Tree for the moons dataset described below.
#
#
#  1. Split it into a training set and a test set using train_test_split().
#
#  2. Use grid search with cross-validation (with the help of the GridSearchCV class) to find good hyperparameter values for a DecisionTreeClassifier. Experiment with different parameters of the Decision tree.
#
#  3. Train it on the full training set using these hyperparameters, and measure your model’s performance on the test set.

# %%
from sklearn.datasets import make_moons
from sklearn.pipeline import Pipeline
# %matplotlib inline
import matplotlib.pyplot as plt


X, y = make_moons(n_samples=10000, noise=0.4, random_state=42)

def plot_dataset(X, y, axes):
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs")
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^")
    plt.axis(axes)
    plt.grid(True, which='both')
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"$x_2$", fontsize=20, rotation=0)

plot_dataset(X, y, [-3, 3, -2, 3])
plt.show()

# %% [markdown]
# Task2
#
# Build a DecisionModel classifier for a mushroom dataset (http://archive.ics.uci.edu/ml/datasets/Mushroom).
# Start with exploratory data analysis to see if all features are relevant.
# Perform hyperparameters optimization using grid search.
# Train the model using optimized hyperparameters.
# Visualize the tree.
# Demonstrate the suboptimal parameter where model is underfitting and overfitting.
